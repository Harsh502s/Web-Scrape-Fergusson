# %%
from bs4 import BeautifulSoup
from requests import get
import pandas as pd
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_4672\1054371810.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Checking the Sites response

url = r"https://medium.com/@harsh502singh/introduction-to-webscraping-using-beautifulsoup-and-requests-d63a0510816a"
response = get(url)
print(response)
# Out:
# <Response [200]>

# %%
url = r"https://medium.com/@harsh502singh/introduction-to-webscraping-using-beautifulsoup-and-requests-d63a0510816a"
response = get(url)
sp = BeautifulSoup(response.text, 'lxml')
print(sp.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title data-rh="true">
#    Introduction to Web Scraping: Using Beautiful Soup and Requests | by Harshit Singh | Medium
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="width=device-width,minimum-scale=1,initial-scale=1,maximum-scale=1" data-rh="true" name="viewport"/>
#   <meta content="#000000" data-rh="true" name="theme-color"/>
#   <meta content="Medium" data-rh="true" name="twitter:app:name:iphone"/>
#   <meta content="828256236" data-rh="true" name="twitter:app:id:iphone"/>
#   <meta content="Medium" data-rh="true" property="al:ios:app_name"/>
#   <meta content="828256236" data-rh="true" property="al:ios:app_store_id"/>
#   <meta content="com.medium.reader" data-rh="true" property="al:android:package"/>
#   <meta content="542599432471018" data-rh="true" property="fb:app_id"/>
#   <meta content="Medium" data-rh="true" property="og:site_name"/>
# ...

# %%
url = r"https://www.airlinequality.com/airline-reviews/air-india/"
response = get(url)
soup = BeautifulSoup(response.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9 lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js lt-ie10" lang="en-GB"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en-GB">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Air India Customer Reviews - SKYTRAX
#   </title>
#   <!-- Google Chrome Frame for IE -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <!-- mobile meta -->
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <!-- icons & favicons -->
# ...

# %%
title = soup.find('div' , attrs={'class':'body','id':'anchor888660'}).find('h2').text
body = soup.find('div' , attrs={'class':'body','id':'anchor888660'}).find('div' , class_='tc_mobile').text

# %%
soup.find('div' , attrs={'class':'body','id':'anchor888660'}).find('div' , class_='tc_mobile').text
# Out:
# '\n✅ Trip Verified |  Very third class services of air India. We were in the line at 3.45 am to the airport for 5am flight there was no call given by that supervisor. only 2 people were at the counter. That lady was very unprofessional and not well mannered. She had not accepted our tickets we had to cancel it.  Very disappointed. Horror experience\n\n\nType Of TravellerFamily Leisure\nSeat TypeEconomy Class\nRouteMumbai to Kochi \nDate FlownFebruary 2024\n\nGround Service\n12345\n\n\nValue For Money\n12345\n\nRecommendedno \n\n'

# %%
print(title)
print(body)
# Out:
# "Very disappointed"
#
# ✅ Trip Verified |  Very third class services of air India. We were in the line at 3.45 am to the airport for 5am flight there was no call given by that supervisor. only 2 people were at the counter. That lady was very unprofessional and not well mannered. She had not accepted our tickets we had to cancel it.  Very disappointed. Horror experience
#
#
# Type Of TravellerFamily Leisure
# Seat TypeEconomy Class
# RouteMumbai to Kochi
# Date FlownFebruary 2024
#
# Ground Service
# 12345
#
#
# Value For Money
# 12345
#
# Recommendedno

# %%
article_soup = soup.find_all('article', attrs={'class':"comp comp_reviews-airline querylist position-content"})
article_soup
# Out:
# [<article class="comp comp_reviews-airline querylist position-content">
#  <div class="pagination-controls">
#  <div class="pagination-filter">
#  <form method="get">
#  <span class="pagination-label">Filter Reviews by : </span>
#  <input name="pagesize" type="hidden" value="10"/>
#  <select class="page-filter-selector" data-onchange-submit="" name="filterby">
#  <option selected="" value="">Latest reviews</option>
#  <option value="cabin:first">First Class</option>
#  <option value="cabin:business">Business Class</option>
#  <option value="cabin:p_economy">Premium Economy</option>
#  <option value="cabin:economy">Economy Class</option>
#  </select>
#  </form>
#  </div>
#  <div class="pagination-size">
#  <form method="get">
#  <span class="pagination-label">Show</span>
#  <input name="sortby" type="hidden" value="post_date:Desc"/>
#  <ul class="page-size-selector">
#  <li>
#  <input checked="" data-onchange-submit="" id="10" name="pagesize" type="radio" value="10"/>
# ...

# %%
all_title = [i.find_all('div', attrs={'class':'body'}) for i in article_soup ]
titles = [i.find('h2').text for i in all_title[0]]
titles
# all_body = [i.find('div' , attrs={'class':'body','id':'anchor888660'}).find('div' , class_='tc_mobile') for i in article_soup ]
# Out:
# ['"Very disappointed"',
#  '"extremely dissatisfied with Air India"',
#  '"I asked for compensation" ',
#  '"It’s a bad experience"',
#  '"Very polite cabin crew"',
#  '"horrible, dirty and old"',
#  '"Our worst flying experience"',
#  '“a fabulous experience“',
#  '"Excellent crew, polite and professional"',
#  '"Absolutely the worst flight"']

# %%
all = [i.find_all('div', attrs={'class':'body'}) for i in article_soup ]
all_body = [i.find('div' , class_='tc_mobile').text for i in all[0] ]
print(len(all))
all_body
# Out:
# 1
# ['\n✅ Trip Verified |  Very third class services of air India. We were in the line at 3.45 am to the airport for 5am flight there was no call given by that supervisor. only 2 people were at the counter. That lady was very unprofessional and not well mannered. She had not accepted our tickets we had to cancel it.  Very disappointed. Horror experience\n\n\nType Of TravellerFamily Leisure\nSeat TypeEconomy Class\nRouteMumbai to Kochi \nDate FlownFebruary 2024\n\nGround Service\n12345\n\n\nValue For Money\n12345\n\nRecommendedno \n\n',
# ...

# %%
import pandas as pd

data_dict = {'Title':titles, 'Body':all_body}
df = pd.DataFrame(data_dict)
df
# Out:
#                                        Title  \
# 0                        "Very disappointed"
# 1    "extremely dissatisfied with Air India"
# 2                "I asked for compensation"
# 3                    "It’s a bad experience"
# 4                   "Very polite cabin crew"
# 5                  "horrible, dirty and old"
# 6              "Our worst flying experience"
# 7                    “a fabulous experience“
# 8  "Excellent crew, polite and professional"
# 9              "Absolutely the worst flight"
#
#                                                 Body
# 0  \n✅ Trip Verified |  Very third class services...
# 1  \n✅ Trip Verified |  I am extremely dissatisfi...
# 2  \n✅ Trip Verified |  The airline is part of th...
# 3  \nNot Verified |  It’s a bad experience. The f...
# 4  \n✅ Trip Verified | Had a very good experience...
# 5  \n✅ Trip Verified |  Cancelled flight Hyderaba...
# 6  \n✅ Trip Verified |  Our worst flying experien...
# ...

# %%
https://medium.com/@harsh502singh/introduction-to-webscraping-using-beautifulsoup-and-requests-d63a0510816a
